# %% [markdown]
# <h1>Creating dataset...</h1>

# %%
import pandas as pd
from sklearn import datasets

x, y , coef = datasets.make_regression(n_samples=15,
                                      n_features=1,
                                      n_informative=7,
                                      coef=True)

x,y,coef
# Out:
# (array([[ 0.2820391 ],
#         [ 0.97681688],
#         [-0.17013659],
#         [ 0.78443378],
#         [-0.99012769],
#         [ 1.06157454],
#         [ 0.22156766],
#         [ 0.80200897],
#         [-1.01653624],
#         [ 0.95412939],
#         [-0.29459559],
#         [ 0.28898541],
#         [-0.0655145 ],
#         [ 0.4157606 ],
#         [-0.80771454]]),
#  array([  6.49629036,  22.49931343,  -3.91880665,  18.06809643,
#         -22.8059053 ,  24.45156192,   5.10343369,  18.47291099,
#         -23.41418128,  21.97674568,  -6.78550779,   6.65628682,
#          -1.50901489,   9.57633753, -18.60432895]),
#  array(23.03329717))

# %% [markdown]
# <h1>Reading data</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt


market_info = pd.read_csv('yahoo_stock.csv')

market_info
# Out:
#             Date         High          Low         Open        Close  \
# 0     2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088
# 1     2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893
# 2     2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117
# 3     2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117
# 4     2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107
# ...          ...          ...          ...          ...          ...
# 1820  2020-11-16  3628.510010  3600.159912  3600.159912  3626.909912
# 1821  2020-11-17  3623.110107  3588.679932  3610.310059  3609.530029
# 1822  2020-11-18  3619.090088  3567.330078  3612.090088  3567.790039
# 1823  2020-11-19  3585.219971  3543.840088  3559.409912  3581.870117
# 1824  2020-11-20  3581.229980  3556.850098  3579.310059  3557.540039
#
#             Volume    Adj Close
# 0     3.587980e+09  2086.590088
# 1     3.884930e+09  2089.139893
# 2     2.852940e+09  2088.870117
# ...

# %% [markdown]
# <h1>Splitting,fitting,predicting</h1>

# %%
import sklearn
from sklearn.model_selection import train_test_split


x = market_info[["High","Low","Open","Close"]]
y = market_info[["Volume"]] * (10 **(-9))
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.1)
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
y_Hat = lr.predict(x_test)

fig, ax = plt.subplots()
ax.plot(y_test, 'r.', label = 'tested value')
ax.plot(y_Hat, 'b.', label = 'predicted value')
fig.set_figheight(10)
fig.set_figwidth(30)
ax.legend()
plt.show()
