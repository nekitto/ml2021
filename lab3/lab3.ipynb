# %% [markdown]
# <h1>Creating dataset...</h1>

# %%
import pandas as pd
from sklearn import datasets
import sklearn.datasets

X, y = datasets.make_classification(n_samples=150, n_classes=3,
                           n_features=5, n_informative=3, n_redundant=0,
                           random_state=0)
X,y
# Out:
# (array([[ 7.49688133e-01,  1.32398088e+00, -1.21820797e+00,
#           8.61383002e-02, -1.30129399e+00],
#         [-1.14912376e+00,  1.62101524e+00,  5.36315990e-01,
#          -5.00970786e-01, -9.39583780e-01],
#         [-8.06606856e-01, -1.51928320e+00, -1.43170429e+00,
#           7.73246330e-01, -6.63063271e-01],
#         [ 1.07790748e+00,  1.17139024e+00,  3.75988587e-01,
#          -2.20251153e-02, -1.84345018e+00],
#         [-2.89279430e+00,  1.51111931e+00,  8.07976517e-01,
#          -7.61401332e-01,  1.67667164e+00],
#         [ 3.42057513e-01, -1.76256281e+00, -7.52922727e-01,
#          -5.76887123e-01,  1.94378455e+00],
#         [-1.34346249e-01,  1.29014994e+00,  4.68191491e-01,
#          -7.57249672e-01, -9.60629600e-02],
#         [ 5.08473989e-01,  8.41065222e-01,  9.39602407e-01,
#           2.35333669e-01,  1.31307953e+00],
#         [ 1.99339379e-01,  2.74126092e+00, -1.29796301e+00,
#          -1.39994935e-01,  2.00982547e+00],
# ...

# %% [markdown]
# <h1>Classiffication problem</h1>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

rice_data = pd.read_csv('riceClassification.csv')
rice_data = rice_data.drop(columns=['id'])
x, y = rice_data.drop(columns='Class'), rice_data['Class']
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.9)


import seaborn as sns

sns.FacetGrid(rice_data, hue="Class", size=10).map(plt.scatter, "MajorAxisLength", "MinorAxisLength").add_legend()



from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_hat = knn.predict(x_test)

plt.show()
print("Model accuracy ~ " + str( round( knn.score ( x_test, y_test ) * 100 , 3) ) + "%" )
# Out:
# H:\conda\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# Model accuracy ~ 98.021%
